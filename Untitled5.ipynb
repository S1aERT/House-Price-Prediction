# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\sarth\Downloads\AI\housing.csv")

# %%
print(df)
# Out:
#        longitude  latitude
# 0        -122.23     37.88
# 1        -122.22     37.86
# 2        -122.24     37.85
# 3        -122.25     37.85
# 4        -122.25     37.85
# ...          ...       ...
# 20635    -121.09     39.48
# 20636    -121.21     39.49
# 20637    -121.22     39.43
# 20638    -121.32     39.43
# 20639    -121.24     39.37
#
# [20640 rows x 2 columns]

# %%
df=pd.read_excel(r"C:\Users\sarth\Downloads\BTech_Project_Literature_review_new_paper.xlsx")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/S1aERT/portfolioumm/refs/heads/main/pima-indians-diabetes.data.txt")

# %%
print(df)
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
df.tail()
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   6       767 non-null    int64
#  1   148     767 non-null    int64
#  2   72      767 non-null    int64
#  3   35      767 non-null    int64
#  4   0       767 non-null    int64
#  5   33.6    767 non-null    float64
#  6   0.627   767 non-null    float64
#  7   50      767 non-null    int64
#  8   1       767 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#                 6         148          72          35           0        33.6  \
# count  767.000000  767.000000  767.000000  767.000000  767.000000  767.000000
# mean     3.842243  120.859192   69.101695   20.517601   79.903520   31.990482
# std      3.370877   31.978468   19.368155   15.954059  115.283105    7.889091
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   32.000000   32.000000
# 75%      6.000000  140.000000   80.000000   32.000000  127.500000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#             0.627          50           1
# count  767.000000  767.000000  767.000000
# mean     0.471674   33.219035    0.348110
# std      0.331497   11.752296    0.476682
# min      0.078000   21.000000    0.000000
# 25%      0.243500   24.000000    0.000000
# ...

# %%
df.columns
# Out:
# Index(['6', '148', '72', '35', '0', '33.6', '0.627', '50', '1'], dtype='object')

# %%
df.shape
# Out:
# (767, 9)

# %%
print(df[["6","72"]])
# Out:
#       6  72
# 0     1  66
# 1     8  64
# 2     1  66
# 3     0  40
# 4     5  74
# ..   ..  ..
# 762  10  76
# 763   2  70
# 764   5  72
# 765   1  60
# 766   1  70
#
# [767 rows x 2 columns]

# %%
df.loc[0]
# Out:
# 6         1.000
# 148      85.000
# 72       66.000
# 35       29.000
# 0         0.000
# 33.6     26.600
# 0.627     0.351
# 50       31.000
# 1         0.000
# Name: 0, dtype: float64

# %%
df.iloc[0]
# Out:
# 6         1.000
# 148      85.000
# 72       66.000
# 35       29.000
# 0         0.000
# 33.6     26.600
# 0.627     0.351
# 50       31.000
# 1         0.000
# Name: 0, dtype: float64

# %%
print(df.head())
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
df.loc[0,"6"]
# Out:
# 1

# %%
df.iloc[0:3, 0:2]
# Out:
#    6  148
# 0  1   85
# 1  8  183
# 2  1   89

# %%
df[df["6"]<5]
# Out:
#      6  148  72  35    0  33.6  0.627  50  1
# 0    1   85  66  29    0  26.6  0.351  31  0
# 2    1   89  66  23   94  28.1  0.167  21  0
# 3    0  137  40  35  168  43.1  2.288  33  1
# 5    3   78  50  32   88  31.0  0.248  26  1
# 7    2  197  70  45  543  30.5  0.158  53  1
# ..  ..  ...  ..  ..  ...   ...    ...  .. ..
# 757  1  106  76   0    0  37.5  0.197  26  0
# 759  2   88  58  26   16  28.4  0.766  22  0
# 763  2  122  70  27    0  36.8  0.340  27  0
# 765  1  126  60   0    0  30.1  0.349  47  1
# 766  1   93  70  31    0  30.4  0.315  23  0
#
# [492 rows x 9 columns]

# %%
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df[(df['longitude']< -122.24) & (df['population']<845)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 13       -122.26     37.84                52.0        696.0           191.0
# 15       -122.26     37.85                50.0       1120.0           283.0
# ...          ...       ...                 ...          ...             ...
# 19802    -123.17     40.31                36.0         98.0            28.0
# 19803    -123.22     40.16                27.0       1848.0           449.0
# 19804    -123.48     40.34                19.0        518.0           108.0
# 19805    -123.43     40.22                20.0        133.0            35.0
# 19806    -123.41     40.07                17.0        449.0           151.0
#
# ...

# %%
df.query("longitude<-122.24 and population<845")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 13       -122.26     37.84                52.0        696.0           191.0
# 15       -122.26     37.85                50.0       1120.0           283.0
# ...          ...       ...                 ...          ...             ...
# 19802    -123.17     40.31                36.0         98.0            28.0
# 19803    -123.22     40.16                27.0       1848.0           449.0
# 19804    -123.48     40.34                19.0        518.0           108.0
# 19805    -123.43     40.22                20.0        133.0            35.0
# 19806    -123.41     40.07                17.0        449.0           151.0
#
# ...

# %%
col="longitude"
df.query(f"{col}<-122.24")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# ...          ...       ...                 ...          ...             ...
# 19802    -123.17     40.31                36.0         98.0            28.0
# 19803    -123.22     40.16                27.0       1848.0           449.0
# 19804    -123.48     40.34                19.0        518.0           108.0
# 19805    -123.43     40.22                20.0        133.0            35.0
# 19806    -123.41     40.07                17.0        449.0           151.0
#
# ...

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "A": [1, np.nan, 3, np.nan, 5],
    "B": [np.nan, 20, np.nan, 40, 50],
    "C": [10, 20, np.nan, np.nan, np.nan],
    "D": [np.nan, np.nan, np.nan, 4, 5]
})

print(df)
# Out:
#      A     B     C    D
# 0  1.0   NaN  10.0  NaN
# 1  NaN  20.0  20.0  NaN
# 2  3.0   NaN   NaN  NaN
# 3  NaN  40.0   NaN  4.0
# 4  5.0  50.0   NaN  5.0

# %%
df.bfill()
# Out:
#      A     B     C    D
# 0  1.0  20.0  10.0  4.0
# 1  3.0  20.0  20.0  4.0
# 2  3.0  40.0   NaN  4.0
# 3  5.0  40.0   NaN  4.0
# 4  5.0  50.0   NaN  5.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Bob"],
    "Age":  [25, 30, 35, 25, 30],
    "City": ["Delhi", "Mumbai", "Pune", "Delhi", "Mumbai"]
})

print(df)
# Out:
#       Name  Age    City
# 0    Alice   25   Delhi
# 1      Bob   30  Mumbai
# 2  Charlie   35    Pune
# 3    Alice   25   Delhi
# 4      Bob   30  Mumbai

# %%
df.drop_duplicates()
# Out:
#       Name  Age    City
# 0    Alice   25   Delhi
# 1      Bob   30  Mumbai
# 2  Charlie   35    Pune

# %%
print(df)
# Out:
#       Name  Age    City
# 0    Alice   25   Delhi
# 1      Bob   30  Mumbai
# 2  Charlie   35    Pune
# 3    Alice   25   Delhi
# 4      Bob   30  Mumbai
# 5    Alice   35  London

# %%
df.duplicated(["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
df['Name'].str.lower()
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      alice
# 4        bob
# 5      alice
# Name: Name, dtype: object

# %%
df['City'].str.contains('delhi',case=False)
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: City, dtype: bool

# %%
df
# Out:
#       Name  Age    City
# 0    Alice   25   Delhi
# 1      Bob   30  Mumbai
# 2  Charlie   35    Pune
# 3    Alice   25   Delhi
# 4      Bob   30  Mumbai
# 5    Alice   35  London

# %%
import pandas as pd

df = pd.DataFrame({
    "Email": [
        "alice@gmail.com",
        "bob@yahoo.com",
        "charlie@outlook.com",
        "david@company.org"
    ]
})

print(df)
# Out:
#                  Email
# 0      alice@gmail.com
# 1        bob@yahoo.com
# 2  charlie@outlook.com
# 3    david@company.org

# %%
df['Email'].str.split('@')
# Out:
# 0        [alice, gmail.com]
# 1          [bob, yahoo.com]
# 2    [charlie, outlook.com]
# 3      [david, company.org]
# Name: Email, dtype: object

# %%
print(df)
# Out:
#    Category       Date
# 0      Food 2025-01-05
# 1    Travel 2025-02-10
# 2      Food 2025-02-15
# 3  Shopping 2025-03-01
# 4    Travel 2025-03-10

# %%
df['Age']=df['Age'].astype(float)

# %%
import pandas as pd

df = pd.DataFrame({
    "Category": ["Food", "Travel", "Food", "Shopping", "Travel"],
    "Date": pd.to_datetime([
        "2025-01-05",
        "2025-02-10",
        "2025-02-15",
        "2025-03-01",
        "2025-03-10"
    ])
})

print(df)
# Out:
#    Category       Date
# 0      Food 2025-01-05
# 1    Travel 2025-02-10
# 2      Food 2025-02-15
# 3  Shopping 2025-03-01
# 4    Travel 2025-03-10

# %%
df['Category']=df['Category'].astype("category")

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Category          category
# Date        datetime64[ns]
# dtype: object

# %%
df['Age Group']=df['Age'].apply(lambda x:'Adult' if x>=18 else 'Minor')

# %%
print(df)
# Out:
#       Name  Age    City Age Group
# 0    Alice   25   Delhi     Adult
# 1      Bob   30  Mumbai     Adult
# 2  Charlie   35    Pune     Adult
# 3    Alice   25   Delhi     Adult
# 4      Bob   30  Mumbai     Adult

# %%
df.loc[len(df)]=['Hari','21','Bangalore']

# %%
print(df)
# Out:
#       Name Age       City Age Group
# 0    Alice  25      Delhi     Adult
# 1      Bob  30     Mumbai     Adult
# 2  Charlie  35       Pune     Adult
# 3    Alice  25      Delhi     Adult
# 4      Bob  30     Mumbai     Adult
# 5     Hari  21  Bangalore     Adult

# %%
import pandas as pd

df = pd.DataFrame({
    "Category": ["Food", "Travel", "Food", "Shopping"]
})

print(df)
# Out:
#    Category
# 0      Food
# 1    Travel
# 2      Food
# 3  Shopping

# %%
df['Category']=df['Category'].map({'Food':'1','Travel':'2','Shopping':'3'})

# %%
print(df)
# Out:
#   Category
# 0        1
# 1        2
# 2        1
# 3        3

# %%
print(df)
# Out:
#    Category
# 0       Foo
# 1      Trav
# 2       Foo
# 3  Shopping

# %%
df['Category']=df['Category'].replace({'Food':"Foo", "Travel":"Trav"})

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Bob"],
    "Age":  [25, 30, 35, 25, 30],
    "City": ["Delhi", "Mumbai", "Pune", "Delhi", "Mumbai"]
})

print(df)
# Out:
#       Name  Age    City
# 0    Alice   25   Delhi
# 1      Bob   30  Mumbai
# 2  Charlie   35    Pune
# 3    Alice   25   Delhi
# 4      Bob   30  Mumbai

# %%
df.sort_values(['Name','City'])
# Out:
#       Name Age       City
# 0    Alice  25      Delhi
# 3    Alice  25      Delhi
# 1      Bob  30     Mumbai
# 4      Bob  30     Mumbai
# 2  Charlie  35       Pune
# 6     Hari  21  Bangalore
# 5     Hari  21  bangalore

# %%
print(df)
# Out:
#       Name Age       City
# 0    Alice  25      Delhi
# 1      Bob  30     Mumbai
# 2  Charlie  35       Pune
# 3    Alice  25      Delhi
# 4      Bob  30     Mumbai
# 5     Hari  21  bangalore
# 6     Hari  21  Bangalore

# %%
df.index=['a','b','c','d','e','f','g']

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#       Name Age       City
# 6     Hari  21  Bangalore
# 5     Hari  21  bangalore
# 4      Bob  30     Mumbai
# 3    Alice  25      Delhi
# 2  Charlie  35       Pune
# 1      Bob  30     Mumbai
# 0    Alice  25      Delhi

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Score": [95, 95, 88, 75, 75]
})

print(df)
# Out:
#       Name  Score
# 0    Alice     95
# 1      Bob     95
# 2  Charlie     88
# 3    David     75
# 4     Emma     75

# %%
df['Rank']=df['Score'].rank(ascending=False, method="dense")

# %%
print(df)
# Out:
#       Name  Score  Rank
# 0    Alice     95   1.0
# 1      Bob     95   1.0
# 2  Charlie     88   2.0
# 3    David     75   3.0
# 4     Emma     75   3.0

# %%
print(df)
# Out:
#    Rank  score     name
# a   1.0     95    Alice
# b   1.0     95      Bob
# 2   2.0     88  Charlie
# 3   3.0     75    David
# 4   3.0     75     Emma

# %%
df.rename(columns={"Name":"name",'Score':'score'}, inplace=True)

# %%
df.rename(index={0:'a',1:'b'}, inplace=True)

# %%
df=df[['Rank','score','name']]

# %%
cols=['score']+ [col for col in df.columns if col!='score']

# %%
df=df[cols]

# %%
print(df)
# Out:
#    score  Rank     name
# a     95   1.0    Alice
# b     95   1.0      Bob
# 2     88   2.0  Charlie
# 3     75   3.0    David
# 4     75   3.0     Emma

# %%
import pandas as pd
# Sample DataFrame
data = {
'Name': ['Alice', 'Bob', 'Charlie'],
'Math': [85, 78, 92],
'Science': [90, 82, 89],
'English': [88, 85, 94]
}
df = pd.DataFrame(data)
# Display the DataFrame
print(df)
# Out:
#       Name  Math  Science  English
# 0    Alice    85       90       88
# 1      Bob    78       82       85
# 2  Charlie    92       89       94

# %%
df=df.melt(id_vars=['Name'], value_vars=['Math','Science','English'], var_name='Subject', value_name='Marks')

# %%
print(df)
# Out:
#       Name  Subject  Marks
# 0    Alice     Math     85
# 1      Bob     Math     78
# 2  Charlie     Math     92
# 3    Alice  Science     90
# 4      Bob  Science     82
# 5  Charlie  Science     89
# 6    Alice  English     88
# 7      Bob  English     85
# 8  Charlie  English     94

# %%
df.pivot(index='Name',columns='Subject', values='Marks')
# Out:
# Subject  English  Math  Science
# Name
# Alice         88    85       90
# Bob           85    78       82
# Charlie       94    92       89

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Alice", "Alice", "Alice", "Bob", "Bob"],
    "Subject": ["Math", "Math", "Science", "Math", "Math"],
    "Score": [85, 80, 90, 78, 82]
})

print(df)
# Out:
#     Name  Subject  Score
# 0  Alice     Math     85
# 1  Alice     Math     80
# 2  Alice  Science     90
# 3    Bob     Math     78
# 4    Bob     Math     82

# %%
df.pivot_table(index='Name',columns='Subject', values='Score', aggfunc="mean")
# Out:
# Subject  Math  Science
# Name
# Alice    82.5     90.0
# Bob      80.0      NaN

# %%
df = pd.DataFrame({
"Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
"Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
"Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
"Salary": [85, 90, 78, 85, 92, 88, 75, 80],
"Age": [23, 25, 30, 22, 28, 26, 21, 27],
"JoinDate": pd.to_datetime([
"2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
"2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
])
})

# %%
df.groupby("Team").agg({
    'Salary': 'mean',
    'Age':'max'
})
# Out:
#       Salary  Age
# Team
# A       87.5   25
# B       81.5   30
# C       90.0   28
# D       77.5   27

# %%
df['Team_Average']=df.groupby("Team")["Salary"]. transform("mean")

# %%
print(df)
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Team_Average
# 0         HR    A      M      85   23 2020-01-10          87.5
# 1         HR    A      F      90   25 2020-02-15          87.5
# 2         IT    B      M      78   30 2021-03-20          81.5
# 3         IT    B      F      85   22 2021-04-10          81.5
# 4  Marketing    C      M      92   28 2020-05-30          90.0
# 5  Marketing    C      F      88   26 2020-06-25          90.0
# 6      Sales    D      M      75   21 2021-07-15          77.5
# 7      Sales    D      F      80   27 2021-08-01          77.5

# %%
df.groupby("Team").filter(lambda x: x['Salary'].mean() >80)
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Team_Average
# 0         HR    A      M      85   23 2020-01-10          87.5
# 1         HR    A      F      90   25 2020-02-15          87.5
# 2         IT    B      M      78   30 2021-03-20          81.5
# 3         IT    B      F      85   22 2021-04-10          81.5
# 4  Marketing    C      M      92   28 2020-05-30          90.0
# 5  Marketing    C      F      88   26 2020-06-25          90.0

# %%
employees = pd.DataFrame({
"EmpID": [1, 2, 3],
"Name": ["Alice", "Bob", "Charlie"],
"DeptID": [10, 20, 30]
})
departments = pd.DataFrame({
"DeptID": [10, 20, 40],
"DeptName": ["HR", "Engineering", "Marketing"]
})

# %%
pd.merge(employees, departments, on="DeptID", how='right')
# Out:
#    EmpID   Name  DeptID     DeptName
# 0    1.0  Alice      10           HR
# 1    2.0    Bob      20  Engineering
# 2    NaN    NaN      40    Marketing

# %%
pd.merge(employees, departments, right_index=True, left_index=True, how='right')
# Out:
#    EmpID     Name  DeptID_x  DeptID_y     DeptName
# 0      1    Alice        10        10           HR
# 1      2      Bob        20        20  Engineering
# 2      3  Charlie        30        40    Marketing

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"]})

# %%
print(df1)
# Out:
#     Name
# 0  Alice
# 1    Bob

# %%
print(df2)
# Out:
#       Name
# 0  Charlie
# 1    David

# %%
pd.merge([df1,df2], on="DeptID", how='right')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[250], line 1
# ----> 1 pd.merge([df1,df2], on="DeptID", how='right')
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
df1 = pd.DataFrame({"ID": [1, 2]})
df2 = pd.DataFrame({"Score": [90, 80]})

# %%
pd.concat([df1,df2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[241], line 1
# ----> 1 pd.concat([df1,df2], how='right')
#
# TypeError: concat() got an unexpected keyword argument 'how'

# %%
df1.join(df2, how='right')
# Out:
#    ID  Score
# 0   1     90
# 1   2     80
